# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
output = np.load('test_output/0.npy')

# %%
output.shape
# Out:
# (3, 128, 256)

# %%
ax, fig = plt.subplots(1, 2, figsize=(10, 20))
plt.imshow(output[0, :, :])
plt.imshow(output[2, :, :])
plt.colorbar()

# %%
plt.imshow(output[1, :, :])
